# %%
import pandas as pd
import numpy as np 
import yfinance as yf 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
tesla=yf.Ticker('TSLA')
df=tesla.history(period='1y')

# %%
df.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  251.000000  251.000000  251.000000  251.000000  2.510000e+02
# mean   398.074781  405.167211  390.691395  398.055100  7.459080e+07
# std     48.203654   48.714522   47.066656   47.887521  2.491713e+07
# min    291.369995  296.149994  288.769989  293.940002  3.243500e+07
# 25%    359.590012  367.460007  348.865005  354.050003  5.768790e+07
# 50%    407.290009  415.829987  399.179993  408.579987  6.830550e+07
# 75%    436.605011  442.809998  427.350006  435.370010  8.713750e+07
# max    489.880005  498.829987  485.329987  489.880005  1.907168e+08
#
#        Dividends  Stock Splits
# count      251.0         251.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
df=df.drop(['Dividends','Stock Splits'],axis=1)

# %%
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-06-20 00:00:00-04:00  327.950012  332.359985  317.779999  322.160004
# 2025-06-23 00:00:00-04:00  327.540009  357.540009  327.480011  348.679993
# 2025-06-24 00:00:00-04:00  356.170013  356.260010  340.440002  340.470001
# 2025-06-25 00:00:00-04:00  342.700012  343.000000  320.399994  327.549988
# 2025-06-26 00:00:00-04:00  324.609985  331.049988  323.609985  325.779999
#
#                               Volume
# Date
# 2025-06-20 00:00:00-04:00  108688000
# 2025-06-23 00:00:00-04:00  190716800
# 2025-06-24 00:00:00-04:00  114736200
# 2025-06-25 00:00:00-04:00  119845100
# 2025-06-26 00:00:00-04:00   80440900

# %%
df['Next_Day_Closing']=df['Close'].shift(-1)

# %%
df=df.dropna()
x = df[['Open','High','Low','Close','Volume']]
y = df['Next_Day_Closing']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr=lr.predict(x_test)

# %%
mse_lr=mean_squared_error(y_test,y_pred_lr)
r2_lr=r2_score(y_test,y_pred_lr)

# %%
print("MSE_IR",mse_lr)
print("R2_Score_IR",r2_lr)
# Out:
# MSE_IR 128.59255532776663
# R2_Score_IR 0.946351370608642

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf=rf.predict(x_test)

# %%
mse_rf=mean_squared_error(y_test,y_pred_rf)
r2_rf=r2_score(y_test,y_pred_rf)

# %%
print("MSE_RF",mse_rf)
print("R2_Score_RF",r2_rf)
# Out:
# MSE_RF 122.27611520971199
# R2_Score_RF 0.9489865803538912

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test.values,label='REAL PRICES',color='black',linewidth=2)
plt.plot(y_pred_lr,label='Linear Reggression',color='red',linestyle='--')
plt.plot(y_pred_rf,label='RandomForest',color='blue',linestyle='--')
plt.title('Actual vs Predicted Stock Price')
plt.xlabel('Time (Days)')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
