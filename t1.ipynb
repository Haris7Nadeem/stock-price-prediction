# %%
import pandas as pd
import numpy as np 
import yfinance as yf 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
tesla=yf.Ticker('TSLA')
df=tesla.history(period='1mo')

# %%
df.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count   22.000000   22.000000   22.000000   22.000000  2.200000e+01
# mean   414.261819  420.802730  405.589547  413.423637  4.685639e+07
# std     15.627755   14.462678   17.839239   16.310360  8.166553e+06
# min    388.279999  397.089996  380.149994  381.589996  3.243500e+07
# 25%    401.937500  408.114998  389.849998  401.394989  4.377590e+07
# 50%    415.294998  421.460007  406.745010  413.514999  4.530950e+07
# 75%    422.547508  431.032509  416.870003  423.729996  4.889685e+07
# max    442.890015  445.600006  436.299988  442.100006  6.351450e+07
#
#        Dividends  Stock Splits
# count       22.0          22.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
df=df.drop(['Dividends','Stock Splits'],axis=1)

# %%
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-05-19 00:00:00-04:00  403.160004  405.630005  393.630005  404.109985
# 2026-05-20 00:00:00-04:00  407.600006  417.459991  406.390015  417.260010
# 2026-05-21 00:00:00-04:00  422.179993  426.950012  412.899994  417.850006
# 2026-05-22 00:00:00-04:00  422.670013  431.510010  420.510010  426.010010
# 2026-05-26 00:00:00-04:00  430.260010  435.200012  426.119995  433.589996
#
#                              Volume
# Date
# 2026-05-19 00:00:00-04:00  46500600
# 2026-05-20 00:00:00-04:00  45294700
# 2026-05-21 00:00:00-04:00  42636900
# 2026-05-22 00:00:00-04:00  46104700
# 2026-05-26 00:00:00-04:00  45658900

# %%
df['Next_Day_Closing']=df['Close'].shift(-1)

# %%
df=df.dropna()
x = df[['Open','High','Low','Close','Volume']]
y = df['Next_Day_Closing']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr=lr.predict(x_test)

# %%
mse_lr=mean_squared_error(y_test,y_pred_lr)
r2_lr=r2_score(y_test,y_pred_lr)

# %%
print("MSE_IR",mse_lr)
print("R2_Score_IR",r2_lr)
# Out:
# MSE_IR 156.67786996883297
# R2_Score_IR -1.245837653968192

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf=rf.predict(x_test)

# %%
mse_rf=mean_squared_error(y_test,y_pred_rf)
r2_rf=r2_score(y_test,y_pred_rf)

# %%
print("MSE_RF",mse_rf)
print("R2_Score_RF",r2_rf)
# Out:
# MSE_RF 178.8139173870245
# R2_Score_RF -1.56313816878684

# %%
plt.Figure(figsize=(12,6))
plt.plot(y_test.values,label='REAL PRICES',color='black',linewidth=2)
plt.plot(y_pred_lr,label='Linear Reggression',color='red',linestyle='--')
plt.plot(y_pred_rf,label='RandomForest',color='blue',linestyle='--')
plt.title('Actual vs Predicted Stock Price')
plt.xlabel('Time (Days)')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
